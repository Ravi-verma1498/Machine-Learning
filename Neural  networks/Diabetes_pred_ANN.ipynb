# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/content/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.corr()['Outcome']




x = df.drop(columns = ['Outcome'])
y = df['Outcome']
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
import tensorflow as tf

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
x = st.fit_transform(x)
# x = pd.DataFrame(x)
x
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2, random_state=42)

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense ,Dropout

# %%
model = Sequential()
model.add(Dense(32,activation = 'relu',input_dim = 8))
model.add(Dense(1,activation = 'sigmoid'))
model.compile(optimizer = 'Adam',loss = "binary_crossentropy",metrics = ['accuracy'])

# %%
model.fit(xtrain,ytrain,batch_size = 32,epochs = 10,validation_data=(xtest,ytest))
# Out:
# Epoch 1/10
# 20/20 [==============================] - 1s 13ms/step - loss: 0.6316 - accuracy: 0.6873 - val_loss: 0.5898 - val_accuracy: 0.7403
# Epoch 2/10
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5926 - accuracy: 0.7280 - val_loss: 0.5603 - val_accuracy: 0.7597
# Epoch 3/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5644 - accuracy: 0.7459 - val_loss: 0.5417 - val_accuracy: 0.7792
# Epoch 4/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5419 - accuracy: 0.7508 - val_loss: 0.5263 - val_accuracy: 0.7922
# Epoch 5/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5250 - accuracy: 0.7524 - val_loss: 0.5151 - val_accuracy: 0.7922
# Epoch 6/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5105 - accuracy: 0.7541 - val_loss: 0.5072 - val_accuracy: 0.7857
# Epoch 7/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4993 - accuracy: 0.7573 - val_loss: 0.5021 - val_accuracy: 0.7857
# Epoch 8/10
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4908 - accuracy: 0.7590 - val_loss: 0.4992 - val_accuracy: 0.7792
# Epoch 9/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4843 - accuracy: 0.7671 - val_loss: 0.4980 - val_accuracy: 0.7857
# Epoch 10/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4786 - accuracy: 0.7655 - val_loss: 0.4991 - val_accuracy: 0.7857
